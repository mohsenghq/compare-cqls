# %%
# !git clone https://github.com/mohsenghq/compare-cqls.git
# %cd compare-cqls
# Out:
# Cloning into 'compare-cqls'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 14 (delta 4), reused 13 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 6.10 KiB | 3.05 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /kaggle/working/compare-cqls

# %%
# !pip -q install minari d3rlpy
# !pip -q install "gymnasium[mujoco]"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 10.1 MB/s eta 0:00:0000:010:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# WARNING: typer 0.15.2 does not provide the extra 'all'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.1/201.1 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 35.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.0 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 31.0 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !python load_dataset.py
# Out:
# 2025-05-20 12:48.58 [info     ] Register Shimmy environments.
# namespace_metadata.json: 100%|█████████████| 1.31k/1.31k [00:00<00:00, 10.1MB/s]
# metadata.json: 100%|███████████████████████| 1.78k/1.78k [00:00<00:00, 19.2MB/s]
# namespace_metadata.json: 100%|█████████████| 1.68k/1.68k [00:00<00:00, 13.3MB/s]
# namespace_metadata.json: 100%|█████████████| 10.9k/10.9k [00:00<00:00, 10.2MB/s]
# namespace_metadata.json: 100%|█████████████| 2.72k/2.72k [00:00<00:00, 24.6MB/s]
# namespace_metadata.json: 100%|█████████████| 3.09k/3.09k [00:00<00:00, 32.1MB/s]
# namespace_metadata.json: 100%|████████████████| 38.0/38.0 [00:00<00:00, 360kB/s]
# namespace_metadata.json: 100%|█████████████| 1.31k/1.31k [00:00<00:00, 12.0MB/s]
# namespace_metadata.json: 100%|██████████████████| 121/121 [00:00<00:00, 865kB/s]
#
# ...
# Fetching 2 files:   0%|                                   | 0/2 [00:00<?, ?it/s]
# main_data.hdf5:   0%|                                | 0.00/210M [00:00<?, ?B/s]
# ...

# %%
# !python train_cql.py
# Out:
# 2025-05-20 12:49.13 [info     ] Register Shimmy environments.
# 2025-05-20 12:49.13 [info     ] Signatures have been automatically determined. action_signature=Signature(dtype=[dtype('float32')], shape=[(6,)]) observation_signature=Signature(dtype=[dtype('float64')], shape=[(17,)]) reward_signature=Signature(dtype=[dtype('float64')], shape=[(1,)])
# 2025-05-20 12:49.13 [info     ] Action-space has been automatically determined. action_space=<ActionSpace.CONTINUOUS: 1>
# 2025-05-20 12:49.13 [info     ] Action size has been automatically determined. action_size=6
# 2025-05-20 12:49.17 [info     ] dataset info                   dataset_info=DatasetInfo(observation_signature=Signature(dtype=[dtype('float64')], shape=[(17,)]), action_signature=Signature(dtype=[dtype('float32')], shape=[(6,)]), reward_signature=Signature(dtype=[dtype('float64')], shape=[(1,)]), action_space=<ActionSpace.CONTINUOUS: 1>, action_size=6)
# ...

# %%
# !python train_misa_cql.py
# Out:
# 2025-05-20 13:04.04 [info     ] Register Shimmy environments.
# 2025-05-20 13:04.05 [info     ] Signatures have been automatically determined. action_signature=Signature(dtype=[dtype('float32')], shape=[(6,)]) observation_signature=Signature(dtype=[dtype('float64')], shape=[(17,)]) reward_signature=Signature(dtype=[dtype('float64')], shape=[(1,)])
# 2025-05-20 13:04.05 [info     ] Action-space has been automatically determined. action_space=<ActionSpace.CONTINUOUS: 1>
# 2025-05-20 13:04.05 [info     ] Action size has been automatically determined. action_size=6
# 2025-05-20 13:04.07 [info     ] dataset info                   dataset_info=DatasetInfo(observation_signature=Signature(dtype=[dtype('float64')], shape=[(17,)]), action_signature=Signature(dtype=[dtype('float32')], shape=[(6,)]), reward_signature=Signature(dtype=[dtype('float64')], shape=[(1,)]), action_space=<ActionSpace.CONTINUOUS: 1>, action_size=6)
# ...

# %%
# !python train_misa_cql_heydari.py
# Out:
# 2025-05-20 13:18.16 [info     ] Register Shimmy environments.
# 2025-05-20 13:18.17 [info     ] Signatures have been automatically determined. action_signature=Signature(dtype=[dtype('float32')], shape=[(6,)]) observation_signature=Signature(dtype=[dtype('float64')], shape=[(17,)]) reward_signature=Signature(dtype=[dtype('float64')], shape=[(1,)])
# 2025-05-20 13:18.17 [info     ] Action-space has been automatically determined. action_space=<ActionSpace.CONTINUOUS: 1>
# 2025-05-20 13:18.17 [info     ] Action size has been automatically determined. action_size=6
# 2025-05-20 13:18.19 [info     ] dataset info                   dataset_info=DatasetInfo(observation_signature=Signature(dtype=[dtype('float64')], shape=[(17,)]), action_signature=Signature(dtype=[dtype('float32')], shape=[(6,)]), reward_signature=Signature(dtype=[dtype('float64')], shape=[(1,)]), action_space=<ActionSpace.CONTINUOUS: 1>, action_size=6)
# ...

# %%
# %matplotlib inline
# !python evaluate_agents.py
# Out:
# 2025-05-20 13:32.35 [info     ] Register Shimmy environments.
# Loading models...
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:517: DeprecationWarning: WARN: The environment HalfCheetah-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# Evaluating CQL...
#   Mean reward: -457.02 ± 0.00
#   Mean episode length: 1000.00
# Evaluating MISA...
#   Mean reward: -838.79 ± 0.00
#   Mean episode length: 1000.00
# Evaluating MISA heydari...
#   Mean reward: -142.54 ± 0.00
#   Mean episode length: 1000.00
#
# Model Comparison:
# CQL: -457.02 ± 0.00
# MISA: -838.79 ± 0.00
# MISA heydari: -142.54 ± 0.00
# Figure(1200x800)
